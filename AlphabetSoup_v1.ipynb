# %% [markdown]
# <a href="https://colab.research.google.com/github/dmldatasci/nonprofit-seeding-deep-learning/blob/main/AlphabetSoup_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alphabet Soup Application Classifier
#
# ## Data Preprocessing

# %%
# load dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
application_df = pd.read_csv('https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv')
application_df.head(5)
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# drop the non-beneficial ID columns, 'EIN' and 'NAME'
application_df = application_df.drop(['EIN', 'NAME'], axis=1)
application_df.head(5)
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# determine the number of unique values in each column
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# choose a cutoff value and create a list of application types to be replaced
app_counts = pd.DataFrame({'APPLICATION_TYPE' : application_df['APPLICATION_TYPE'].value_counts().index, 
                           'counts' : application_df['APPLICATION_TYPE'].value_counts().values}).set_index('APPLICATION_TYPE')
application_types_to_replace = app_counts.loc[app_counts['counts'] <= 500].index

# replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# look at CLASSIFICATION value counts >1
app_counts = application_df['CLASSIFICATION'].value_counts()
app_counts[app_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# choose a cutoff value and create a list of classifications to be replaced
classifications_to_replace = app_counts[app_counts < 1800].index

# replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# convert categorical data to numeric with `pd.get_dummies`
cat_var = [col for col in application_df if application_df[col].dtypes=='object']

dummy_df = pd.get_dummies(application_df[cat_var])
dummy_df.head(5)
# Out:
#    APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0                   False                  True                 False
# 1                   False                 False                 False
# 2                   False                 False                 False
# 3                   False                 False                 False
# 4                   False                 False                 False
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                False                False                False
# 1                 True                False                False
# 2                False                False                 True
# 3                 True                False                False
# 4                 True                False                False
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    AFFILIATION_CompanySponsored  ...  INCOME_AMT_1-9999  \
# 0                         False  ...              False
# 1                         False  ...               True
# 2                          True  ...              False
# 3                          True  ...              False
# 4                         False  ...              False
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                    True                     False               False
# 4                   False                      True               False
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0             False                   False            False
# 1             False                   False            False
# 2             False                   False            False
# 3             False                   False            False
# 4             False                   False            False
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0              False                      True                     False
# 1              False                      True                     False
# 2              False                      True                     False
# 3              False                      True                     False
# 4              False                      True                     False
#
# [5 rows x 41 columns]

# %%
# incorporate dummy variables into the data frame and drop categorical variables
clean_df = pd.concat([application_df, dummy_df], axis=1)
clean_df = clean_df.drop(cat_var, axis=1)
clean_df.head(5)
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# split our preprocessed data into our features and target arrays
X = clean_df.drop('IS_SUCCESSFUL', axis=1)
y = clean_df['IS_SUCCESSFUL']

# split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=80)
print(f"""
The dimensions of X_train are {X_train.shape}.
The dimensions of X_test are {X_test.shape}.
The dimensions of y_train are {y_train.shape}.
The dimensions of y_test are {y_test.shape}.
""")
# Out:
# The dimensions of X_train are (25724, 43).
# The dimensions of X_test are (8575, 43).
# The dimensions of y_train are (25724,).
# The dimensions of y_test are (8575,).

# %%
# instantiate a StandardScaler
scaler = StandardScaler()

# fit the StandardScaler
X_scaler = scaler.fit(X_train)

# scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train & Evaluate the Model

# %%
nn_model = tf.keras.models.Sequential()

# define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model.add(tf.keras.layers.Dense(units=120, activation="relu", input_dim=43))

# first hidden layer
nn_model.add(tf.keras.layers.Dense(units=100, activation="relu"))

# second hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, activation="relu"))

# output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 120)               5280
#
#  dense_1 (Dense)             (None, 100)               12100
#
#  dense_2 (Dense)             (None, 80)                8080
#
#  dense_3 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 25541 (99.77 KB)
# Trainable params: 25541 (99.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 825us/step - loss: 0.5661 - accuracy: 0.7241
# Epoch 2/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5538 - accuracy: 0.7306
# Epoch 3/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5515 - accuracy: 0.7320
# Epoch 4/200
# 804/804 [==============================] - 1s 861us/step - loss: 0.5495 - accuracy: 0.7315
# Epoch 5/200
# 804/804 [==============================] - 0s 604us/step - loss: 0.5484 - accuracy: 0.7320
# Epoch 6/200
# 804/804 [==============================] - 1s 679us/step - loss: 0.5473 - accuracy: 0.7344
# Epoch 7/200
# 804/804 [==============================] - 0s 601us/step - loss: 0.5464 - accuracy: 0.7340
# Epoch 8/200
# 804/804 [==============================] - 0s 608us/step - loss: 0.5460 - accuracy: 0.7341
# Epoch 9/200
# 804/804 [==============================] - 1s 663us/step - loss: 0.5454 - accuracy: 0.7345
# Epoch 10/200
# 804/804 [==============================] - 1s 647us/step - loss: 0.5449 - accuracy: 0.7339
# Epoch 11/200
# 804/804 [==============================] - 1s 626us/step - loss: 0.5444 - accuracy: 0.7357
# Epoch 12/200
# 804/804 [==============================] - 1s 638us/step - loss: 0.5441 - accuracy: 0.7353
# Epoch 13/200
# 804/804 [==============================] - 0s 611us/step - loss: 0.5434 - accuracy: 0.7357
# Epoch 14/200
# 804/804 [==============================] - 0s 605us/step - loss: 0.5430 - accuracy: 0.7344
# Epoch 15/200
# 804/804 [==============================] - 1s 633us/step - loss: 0.5424 - accuracy: 0.7363
# Epoch 16/200
# 804/804 [==============================] - 1s 645us/step - loss: 0.5427 - accuracy: 0.7345
# Epoch 17/200
# 804/804 [==============================] - 1s 705us/step - loss: 0.5414 - accuracy: 0.7358
# Epoch 18/200
# Epoch 113/200
# 804/804 [==============================] - 0s 581us/step - loss: 0.5308 - accuracy: 0.7406
# Epoch 114/200
# 804/804 [==============================] - 0s 611us/step - loss: 0.5307 - accuracy: 0.7409
# Epoch 115/200
# 804/804 [==============================] - 0s 586us/step - loss: 0.5322 - accuracy: 0.7410
# Epoch 116/200
# 804/804 [==============================] - 0s 579us/step - loss: 0.5309 - accuracy: 0.7418
# Epoch 117/200
# 804/804 [==============================] - 0s 583us/step - loss: 0.5306 - accuracy: 0.7413
# Epoch 118/200
# 804/804 [==============================] - 0s 579us/step - loss: 0.5306 - accuracy: 0.7415
# Epoch 119/200
# 804/804 [==============================] - 0s 609us/step - loss: 0.5313 - accuracy: 0.7406
# Epoch 120/200
# 804/804 [==============================] - 0s 579us/step - loss: 0.5314 - accuracy: 0.7409
# Epoch 121/200
# 804/804 [==============================] - 0s 589us/step - loss: 0.5303 - accuracy: 0.7406
# Epoch 122/200
# 804/804 [==============================] - 0s 593us/step - loss: 0.5320 - accuracy: 0.7412
# Epoch 123/200
# 804/804 [==============================] - 1s 630us/step - loss: 0.5304 - accuracy: 0.7413
# Epoch 124/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5304 - accuracy: 0.7414
# Epoch 125/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7416
# Epoch 126/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7411
# Epoch 127/200
# 804/804 [==============================] - 0s 563us/step - loss: 0.5310 - accuracy: 0.7411
# Epoch 128/200
# 804/804 [==============================] - 1s 821us/step - loss: 0.5316 - accuracy: 0.7417
# Epoch 129/200
# 804/804 [==============================] - 0s 612us/step - loss: 0.5304 - accuracy: 0.7409
# Epoch 130/200
# 804/804 [==============================] - 0s 571us/step - loss: 0.5306 - accuracy: 0.7414
# Epoch 131/200
# 804/804 [==============================] - 0s 582us/step - loss: 0.5305 - accuracy: 0.7422
# Epoch 132/200
# 804/804 [==============================] - 0s 580us/step - loss: 0.5304 - accuracy: 0.7421
# Epoch 133/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5307 - accuracy: 0.7414
# Epoch 134/200
# 804/804 [==============================] - 1s 636us/step - loss: 0.5303 - accuracy: 0.7419
# Epoch 135/200
# 804/804 [==============================] - 0s 572us/step - loss: 0.5306 - accuracy: 0.7421
# Epoch 136/200
# 804/804 [==============================] - 0s 578us/step - loss: 0.5313 - accuracy: 0.7410
# Epoch 137/200
# 804/804 [==============================] - 0s 599us/step - loss: 0.5308 - accuracy: 0.7412
# Epoch 138/200
# 804/804 [==============================] - 0s 593us/step - loss: 0.5306 - accuracy: 0.7412
# Epoch 139/200
# 804/804 [==============================] - 0s 569us/step - loss: 0.5313 - accuracy: 0.7419
# Epoch 140/200
# 804/804 [==============================] - 0s 585us/step - loss: 0.5300 - accuracy: 0.7412
# Epoch 141/200
# 804/804 [==============================] - 0s 574us/step - loss: 0.5301 - accuracy: 0.7417
# Epoch 142/200
# 804/804 [==============================] - 0s 614us/step - loss: 0.5320 - accuracy: 0.7408
# Epoch 143/200
# 804/804 [==============================] - 0s 588us/step - loss: 0.5309 - accuracy: 0.7416
# Epoch 144/200
# 804/804 [==============================] - 0s 598us/step - loss: 0.5307 - accuracy: 0.7418
# Epoch 145/200
# 804/804 [==============================] - 1s 978us/step - loss: 0.5299 - accuracy: 0.7414
# Epoch 146/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7427
# Epoch 147/200
# 804/804 [==============================] - 0s 601us/step - loss: 0.5298 - accuracy: 0.7414
# Epoch 148/200
# 804/804 [==============================] - 1s 715us/step - loss: 0.5304 - accuracy: 0.7416
# Epoch 149/200
# 804/804 [==============================] - 0s 587us/step - loss: 0.5303 - accuracy: 0.7416
# Epoch 150/200
# 804/804 [==============================] - 1s 637us/step - loss: 0.5302 - accuracy: 0.7416
# Epoch 151/200
# 804/804 [==============================] - 1s 655us/step - loss: 0.5302 - accuracy: 0.7411
# Epoch 152/200
# 804/804 [==============================] - 1s 647us/step - loss: 0.5304 - accuracy: 0.7417
# Epoch 153/200
# 804/804 [==============================] - 0s 573us/step - loss: 0.5305 - accuracy: 0.7417
# Epoch 154/200
# 804/804 [==============================] - 0s 572us/step - loss: 0.5306 - accuracy: 0.7420
# Epoch 155/200
# 804/804 [==============================] - 0s 587us/step - loss: 0.5305 - accuracy: 0.7413
# Epoch 156/200
# 804/804 [==============================] - 0s 589us/step - loss: 0.5303 - accuracy: 0.7420
# Epoch 157/200
# 804/804 [==============================] - 0s 588us/step - loss: 0.5302 - accuracy: 0.7416
# Epoch 158/200
# 804/804 [==============================] - 0s 578us/step - loss: 0.5299 - accuracy: 0.7415
# Epoch 159/200
# 804/804 [==============================] - 0s 600us/step - loss: 0.5298 - accuracy: 0.7421
# Epoch 160/200
# 804/804 [==============================] - 0s 569us/step - loss: 0.5299 - accuracy: 0.7420
# Epoch 161/200
# 804/804 [==============================] - 0s 563us/step - loss: 0.5301 - accuracy: 0.7413
# Epoch 162/200
# 804/804 [==============================] - 0s 557us/step - loss: 0.5306 - accuracy: 0.7410
# Epoch 163/200
# 804/804 [==============================] - 0s 594us/step - loss: 0.5300 - accuracy: 0.7414
# Epoch 164/200
# 804/804 [==============================] - 0s 554us/step - loss: 0.5305 - accuracy: 0.7414
# Epoch 165/200
# 804/804 [==============================] - 0s 565us/step - loss: 0.5301 - accuracy: 0.7423
# Epoch 166/200
# 804/804 [==============================] - 0s 602us/step - loss: 0.5306 - accuracy: 0.7412
# Epoch 167/200
# 804/804 [==============================] - 0s 560us/step - loss: 0.5296 - accuracy: 0.7417
# Epoch 168/200
# 804/804 [==============================] - 0s 558us/step - loss: 0.5299 - accuracy: 0.7414
# Epoch 169/200
# 804/804 [==============================] - 1s 881us/step - loss: 0.5301 - accuracy: 0.7424
# Epoch 170/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5296 - accuracy: 0.7420
# Epoch 171/200
# 804/804 [==============================] - 1s 627us/step - loss: 0.5295 - accuracy: 0.7420
# Epoch 172/200
# 804/804 [==============================] - 1s 779us/step - loss: 0.5300 - accuracy: 0.7411
# Epoch 173/200
# 804/804 [==============================] - 0s 589us/step - loss: 0.5317 - accuracy: 0.7415
# Epoch 174/200
# 804/804 [==============================] - 0s 595us/step - loss: 0.5322 - accuracy: 0.7419
# Epoch 175/200
# 804/804 [==============================] - 0s 610us/step - loss: 0.5297 - accuracy: 0.7415
# Epoch 176/200
# 804/804 [==============================] - 0s 604us/step - loss: 0.5300 - accuracy: 0.7421
# Epoch 177/200
# 804/804 [==============================] - 0s 592us/step - loss: 0.5289 - accuracy: 0.7421
# Epoch 178/200
# 804/804 [==============================] - 0s 619us/step - loss: 0.5293 - accuracy: 0.7416
# Epoch 179/200
# 804/804 [==============================] - 0s 615us/step - loss: 0.5299 - accuracy: 0.7425
# Epoch 180/200
# 804/804 [==============================] - 1s 635us/step - loss: 0.5310 - accuracy: 0.7422
# Epoch 181/200
# 804/804 [==============================] - 0s 620us/step - loss: 0.5313 - accuracy: 0.7418
# Epoch 182/200
# 804/804 [==============================] - 0s 574us/step - loss: 0.5305 - accuracy: 0.7420
# Epoch 183/200
# 804/804 [==============================] - 0s 587us/step - loss: 0.5297 - accuracy: 0.7420
# Epoch 184/200
# 804/804 [==============================] - 0s 583us/step - loss: 0.5297 - accuracy: 0.7422
# Epoch 185/200
# 804/804 [==============================] - 0s 611us/step - loss: 0.5294 - accuracy: 0.7423
# Epoch 186/200
# 804/804 [==============================] - 0s 603us/step - loss: 0.5303 - accuracy: 0.7423
# Epoch 187/200
# 804/804 [==============================] - 0s 601us/step - loss: 0.5296 - accuracy: 0.7417
# Epoch 188/200
# 804/804 [==============================] - 1s 920us/step - loss: 0.5296 - accuracy: 0.7414
# Epoch 189/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7421
# Epoch 190/200
# 804/804 [==============================] - 1s 654us/step - loss: 0.5307 - accuracy: 0.7424
# Epoch 191/200
# 804/804 [==============================] - 0s 600us/step - loss: 0.5290 - accuracy: 0.7420
# Epoch 192/200
# 804/804 [==============================] - 0s 593us/step - loss: 0.5291 - accuracy: 0.7418
# Epoch 193/200
# 804/804 [==============================] - 0s 606us/step - loss: 0.5299 - accuracy: 0.7420
# Epoch 194/200
# 804/804 [==============================] - 1s 627us/step - loss: 0.5294 - accuracy: 0.7419
# Epoch 195/200
# 804/804 [==============================] - 0s 593us/step - loss: 0.5301 - accuracy: 0.7418
# Epoch 196/200
# 804/804 [==============================] - 1s 654us/step - loss: 0.5311 - accuracy: 0.7417
# Epoch 197/200
# 804/804 [==============================] - 0s 610us/step - loss: 0.5296 - accuracy: 0.7414
# Epoch 198/200
# 804/804 [==============================] - 0s 595us/step - loss: 0.5299 - accuracy: 0.7430
# Epoch 199/200
# 804/804 [==============================] - 0s 591us/step - loss: 0.5293 - accuracy: 0.7422
# Epoch 200/200
# 804/804 [==============================] - 0s 587us/step - loss: 0.5297 - accuracy: 0.7415

# %%
# evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=5)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Loss: 0.5980677604675293, Accuracy: 0.7286297082901001

# %%
import matplotlib.pyplot as plt

# create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# plot the accuracy
history_df.plot(y="accuracy")
plt.show()

# %%
# export the v1 model to HDF5 file
nn_model.save("output/AlphabetSoupCharity.h5")
# Out:
# /Users/davidlevy/Documents/Work/education/berkeley_ds/module_challenges/deep-learning-challenge/.venv/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
